# %%
from collections.abc import Callable
import json
import os
from time import sleep
from typing import Any

from dadata import Dadata
from dotenv import load_dotenv
from langgraph_app.api.yazzh_final import ApiClientUnified
import rich


load_dotenv()

async_yazzh_client = ApiClientUnified(verbose=True)


async def do_request(func: Callable, **kwargs) -> dict:
    async with async_yazzh_client as _client:
        result = await func(**kwargs)
        json_res = result['json']
        return json_res['data']

# %%
async with ApiClientUnified() as client:
    await client.search_building_full_text_search('Ленинский проспект 101')
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🚀 ApiAsyncClient initialized                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ─────────────────────────────────────────────── 📡 search_building ────────────────────────────────────────────────
#                                       Request
#  URL:     https://yazzh-geo.gate.petersburg.ru/api/v2/geo/buildings/search/
#  Params:  {'query': 'Ленинский проспект 101', 'count': 5, 'region_of_search': '78'}
# Status: 200
# ╭───────────────────────── Response JSON (search_building) ─────────────────────────╮
# │ {                                                                                 │
# │   "success": true,                                                                │
# ...

# %%
async with ApiClientUnified() as client:
    await client.get_building_info(16378)
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🚀 ApiAsyncClient initialized                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ────────────────────────────────────────────── 📡 get_building_info ───────────────────────────────────────────────
#                                  Request
#  URL:     https://yazzh-geo.gate.petersburg.ru/api/v2/geo/buildings/16378
#  Params:  {'format': 'extended'}
# Status: 200
# ╭────────────────── Response JSON (get_building_info) ──────────────────╮
# │ {                                                                     │
# │   "data": {                                                           │
# │     "id": 16378,                                                      │
# ...

# %%
async with ApiClientUnified() as client:
    await client.get_districts()
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🚀 ApiAsyncClient initialized                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ──────────────────────────────────────────────── 📡 get_districts ─────────────────────────────────────────────────
#                              Request
#  URL:  https://yazzh-geo.gate.petersburg.ru/api/v2/geo/district/
# Status: 200
# ╭─── Response JSON (get_districts) ───╮
# │ {                                   │
# │   "success": true,                  │
# │   "count": 37,                      │
# │   "data": [                         │
# │     {                               │
# │       "is_actual": true,            │
# │       "id": 1,                      │
# │       "name": "Неизвестно",         │
# ...

# %%
async with ApiClientUnified() as client:
    await client.get_management_company(51641)
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🚀 ApiAsyncClient initialized                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ──────────────────────────────────────────── 📡 get_management_company ────────────────────────────────────────────
#                                 Request
#  URL:     https://yazzh-geo.gate.petersburg.ru/api/v1/mancompany/51641
#  Params:  {'region_of_search': '78'}
# Status: 200
# ╭────────────────────────────── Response JSON (get_management_company) ───────────────────────────────╮
# │ {                                                                                                   │
# │   "data": {                                                                                         │
# ...

# %%
async with ApiClientUnified() as client:
    await client.get_mfc_by_building(48804)
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🚀 ApiAsyncClient initialized                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ───────────────────────────────────────────── 📡 get_mfc_by_building ──────────────────────────────────────────────
#                     Request
#  URL:     https://yazzh.gate.petersburg.ru/mfc/
#  Params:  {'id_building': 48804}
# Status: 200
# ╭────────────────────────────────────── Response JSON (get_mfc_by_building) ──────────────────────────────────────╮
# │ {                                                                                                               │
# │   "id": 14,                                                                                                     │
# ...

# %%
async with ApiClientUnified(verbose=False) as client:
    await client.get_all_mfc()

# %%
async with ApiClientUnified() as client:
    await client.get_mfc_by_district('Невский')
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🚀 ApiAsyncClient initialized                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ───────────────────────────────────────────── 📡 get_mfc_by_district ──────────────────────────────────────────────
#                          Request
#  URL:     https://yazzh.gate.petersburg.ru/mfc/district/
#  Params:  {'district': 'Невский'}
# Status: 200
# ╭────────────────────────────────────── Response JSON (get_mfc_by_district) ──────────────────────────────────────╮
# │ {                                                                                                               │
# │   "count": 6,                                                                                                   │
# ...

# %%
# import httpx
# _client = httpx.AsyncClient(timeout=30.0, headers={'region': "78"},)
# x = await _client.get('https://yazzh.gate.petersburg.ru/mfc/nearest/', params= {
#                 'user_pos': f'{30.2528104} {59.837282}',
#                 'distance': 5,
#             }, headers={'region': '78'})

async_yazzh_client = ApiClientUnified(verbose=True)
async with ApiClientUnified() as client:
    await client.get_mfc_nearest_by_coords(59.837282, 30.2528104)
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🚀 ApiAsyncClient initialized                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ────────────────────────────────────────── 📡 get_mfc_nearest_by_coords ───────────────────────────────────────────
#                            Request
#  URL:     https://yazzh.gate.petersburg.ru/mfc/nearest
#  Params:  {'user_pos': '30.2528104 59.837282', 'distance': 5}
# Status: 200
# ╭─────────────────────── Response JSON (get_mfc_nearest_by_coords) ────────────────────────╮
# │ {                                                                                        │
# │   "success": true,                                                                       │
# ...

# %%
async with ApiClientUnified() as client:
    await client.get_polyclinics_by_building(48804)
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🚀 ApiAsyncClient initialized                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ───────────────────────────────────────── 📡 get_polyclinics_by_building ──────────────────────────────────────────
#                         Request
#  URL:     https://yazzh.gate.petersburg.ru/polyclinics/
#  Params:  {'id': 48804}
# Status: 200
# ╭────────────────────── Response JSON (get_polyclinics_by_building) ──────────────────────╮
# │ [                                                                                       │
# │   {                                                                                     │
# │     "id": 36622,                                                                        │
# ...

# %%
async with ApiClientUnified() as client:
    await client.get_linked_schools(48804)
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🚀 ApiAsyncClient initialized                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ────────────────────────────────────────────── 📡 get_linked_schools ──────────────────────────────────────────────
#                             Request
#  URL:     https://yazzh.gate.petersburg.ru/school/linked/48804
#  Params:  {'scheme': 1}
# Status: 200
# ╭────────────────────────────────────── Response JSON (get_linked_schools) ───────────────────────────────────────╮
# │ {                                                                                                               │
# │   "success": true,                                                                                              │
# ...

# %%
async_yazzh_client = ApiClientUnified(verbose=True)
async with ApiClientUnified() as client:
    await client.get_school_by_id(278)
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🚀 ApiAsyncClient initialized                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ─────────────────────────────────────────────── 📡 get_school_by_id ───────────────────────────────────────────────
#                       Request
#  URL:  https://yazzh.gate.petersburg.ru/school/278
# Status: 200
# ╭─────────────────────────────────────── Response JSON (get_school_by_id) ────────────────────────────────────────╮
# │ {                                                                                                               │
# │   "id": 278,                                                                                                    │
# ...

# %%
async_yazzh_client = ApiClientUnified()
async with ApiClientUnified(verbose=False) as client:
    await client.get_schools_map()
#Фикс эндпоинт

# %%
async_yazzh_client = ApiClientUnified(verbose=False)
async with ApiClientUnified() as client:
    await client.get_kindergartens('Невский',2,11)
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🚀 ApiAsyncClient initialized                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ────────────────────────────────────────────── 📡 get_kindergartens ───────────────────────────────────────────────
#                                                       Request
#  URL:     https://yazzh.gate.petersburg.ru/dou/
#  Params:  {'district': 'Невский', 'legal_form': 'Государственная', 'age_year': 2, 'age_month': 11, 'doo_status':
#           'Функционирует', 'count': 10, 'page': 1}
# Status: 200
# ╭─ Response JSON (get_kindergartens) ──╮
# │ {                                    │
# │   "count": 1,                        │
# │   "data": [                          │
# │     {                                │
# ...

# %%
async_yazzh_client = ApiClientUnified(verbose=False)
async with ApiClientUnified(verbose=False) as client:
    await client.get_district_info_by_building(16378)

# %%
async_yazzh_client = ApiClientUnified(verbose=False)
async with ApiClientUnified(verbose=False) as client:
    await client.get_district_info_by_name('Невский')

# %%
async_yazzh_client = ApiClientUnified(verbose=False)
async with ApiClientUnified() as client:
    await client.get_disconnections(16378)
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🚀 ApiAsyncClient initialized                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ────────────────────────────────────────────── 📡 get_disconnections ──────────────────────────────────────────────
#                           Request
#  URL:     https://yazzh.gate.petersburg.ru/disconnections/
#  Params:  {'id': 16378}
# Status: 204
# - Error! JSON Decode Error: Expecting value: line 1 column 1 (char 0)
# Raw text:
# 👋 Client closed

# %%
async_yazzh_client = ApiClientUnified(verbose=False)
async with ApiClientUnified(verbose=False) as client:
    await client.get_sport_events(
        'Невский',
        'Баскетбол',
        14-12-2025
    )

# %%
async_yazzh_client = ApiClientUnified(verbose=False)
async with ApiClientUnified(verbose=False) as client:
    await client.get_sportgrounds(
        'Невский','Футбол'
    )

"""
тут ендпоинт принимает не object_type, а type, но как-то работает... + надо чтобы он принимал массив тк types может быть *args
Можно ещё сделать поиск площадок рядом с домом
"""
# Out:
# '\nтут ендпоинт принимает не object_type, а type, но как-то работает... + надо чтобы он принимал массив тк types может быть *args\nМожно ещё сделать поиск площадок рядом с домом\n'

# %%
async_yazzh_client = ApiClientUnified(verbose=False)
async with ApiClientUnified() as client:
    await client.get_sportgrounds_count(
    )
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🚀 ApiAsyncClient initialized                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ──────────────────────────────────────────── 📡 get_sportgrounds_count ────────────────────────────────────────────
#                           Request
#  URL:  https://yazzh.gate.petersburg.ru/sportgrounds/count/
# Status: 200
# ╭─ Response JSON (get_sportgrounds_count) ─╮
# │ {                                        │
# │   "count": 1679,                         │
# │   "region": "по городу"                  │
# │ }                                        │
# ╰──────────────────────────────────────────╯
# 👋 Client closed

# %%
async_yazzh_client = ApiClientUnified(verbose=False)
async with ApiClientUnified(verbose=False) as client:
    await client.get_events('2025-11-11T17:18:46','2025-12-12T17:18:46'
    )

# %%
async with ApiClientUnified() as client:
    await client.get_event_categories('2025-11-11T17:18:46','2025-12-12T17:18:46')
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🚀 ApiAsyncClient initialized                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ───────────────────────────────────────────── 📡 get_event_categories ─────────────────────────────────────────────
#                                       Request
#  URL:     https://yazzh.gate.petersburg.ru/afisha/category/all/
#  Params:  {'start_date': '2025-11-11T17:18:46', 'end_date': '2025-12-12T17:18:46'}
# Status: 200
# ╭─ Response JSON (get_event_categories) ─╮
# │ {                                      │
# │   "count": 18,                         │
# │   "type": [                            │
# │     "Все",                             │
# │     "Обучающее занятие",               │
# │     "Концерт",                         │
# ...

# %%
async with ApiClientUnified() as client:
    await client.get_pensioner_categories()
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🚀 ApiAsyncClient initialized                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ─────────────────────────────────────────── 📡 get_pensioner_categories ───────────────────────────────────────────
#                                Request
#  URL:  https://yazzh.gate.petersburg.ru/pensioner/services/category/
# Status: 200
# ╭─ Response JSON (get_pensioner_categories) ─╮
# │ {                                          │
# │   "count": 9,                              │
# │   "category": [                            │
# │     "Вокал",                               │
# │     "Здоровье",                            │
# │     "Иностранные языки",                   │
# │     "Клубы по интересам",                  │
# ...

# %%
async with ApiClientUnified(verbose=False) as client:
    await client.get_pensioner_services('Невский','Танцы')

# %%
async with ApiClientUnified(verbose=False) as client:
    await client.get_vet_clinics(59.837282, 30.2528104)

# %%
async with ApiClientUnified() as client:
    await client.get_pet_parks(59.837282, 30.2528104, 7)
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🚀 ApiAsyncClient initialized                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ──────────────────────────────────────────────── 📡 get_pet_parks ─────────────────────────────────────────────────
#                                                       Request
#  URL:     https://yazzh.gate.petersburg.ru/mypets/all-category/
#  Params:  {'type': 'Парк', 'location_latitude': 59.837282, 'location_longitude': 30.2528104, 'location_radius': 7}
# Status: 200
# ╭─────────────── Response JSON (get_pet_parks) ───────────────╮
# │ {                                                           │
# │   "count": 6,                                               │
# │   "data": [                                                 │
# ...

# %%
async with ApiClientUnified(verbose=False) as client:
    await client.get_beautiful_place_routes(district = 'Невский',categoria = 'Природа')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 async with ApiClientUnified(verbose=False) as client:
# ----> 2     await client.get_beautiful_place_routes(district = 'Невский',categoria = 'Природа')
#
# TypeError: ApiClientUnified.get_beautiful_place_routes() got an unexpected keyword argument 'district'

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.search_building_full_text_search(address)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_building_info(id_build)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_districts()

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.search_building_full_text_search(address)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_building_info(id_build)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_districts()

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_management_company(id_build)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_management_company_company(
        company_id='1',
    )

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_mfc_by_building(id_build)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_all_mfc()

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_mfc_by_district(district_example)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_mfc_nearest_by_coords(lat_spb, lon_spb)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_mfc_nearest_by_building(id_build)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_polyclinics_by_building(id_build)

# %%
# ------------- ШКОЛЫ -------------
async with ApiClientUnified(verbose=True) as client:
    await client.get_linked_schools('16378')

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_school_by_id(1)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_schools_map(district=district_example)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_school_kinds()

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_school_profiles()

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_school_stat(district=district_example)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_school_commissions(district_example)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_school_subjects()

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_school_helpful()

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_school_available_spots_by_district(district_example)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_school_by_ogrn('1057812376720')

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_kindergartens(district_example, age_year=3, age_month=0, count=3)

# %%
# ------------- СПРАВКА ПО РАЙОНУ -------------
async with ApiClientUnified(verbose=True) as client:
    await client.get_district_info_by_building(id_build)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_district_info_by_name(district_example)

# %%
# ------------- ОТКЛЮЧЕНИЯ -------------
async with ApiClientUnified(verbose=True) as client:
    await client.get_disconnections(id_build)

# %%
# ------------- СПОРТ (СПИСОК) -------------
async with ApiClientUnified(verbose=True) as client:
    await client.get_sport_events(district=district_example, count=3)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_sportgrounds(district=district_example, count=3)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_sportgrounds_count()

# %%
import asyncio
from langgraph_app.api.yazzh_final_wip import ApiClientUnified



lat_spb = 59.848975
lon_spb = 30.2192988
district_example = 'Кировский'
id_build = '16378'
address = 'г.Санкт-Петербург, Ленинский проспект, дом 101'

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.search_building_legacy(address, count=3)
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🚀 ApiAsyncClient initialized                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🚀 ApiAsyncClient initialized                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ─────────────────────────────────────────────── 📡 search_building ────────────────────────────────────────────────
#                                                   Request
#  URL:     https://yazzh-geo.gate.petersburg.ru/api/v2/geo/buildings/search/
# ...

# %%
async with ApiClientUnified(verbose=False) as client:
    await client.get_events(
        start_date='2025-11-11T17:18:46',
        end_date='2025-12-12T17:18:46',
        district=district_example,
        count=3,
    )

# %%
async with ApiClientUnified(verbose=False) as client:
    await client.get_vet_clinics(lat=lat_spb, lon=lon_spb)

# %%
async with ApiClientUnified(verbose=False) as client:
    await client.get_event_categories(
        start_date='2025-11-11T17:18:46',
        end_date='2025-12-12T17:18:46',
    )

# %%
# ------------- ПЕНСИОНЕРЫ -------------
async with ApiClientUnified(verbose=False) as client:
    await client.get_pensioner_categories()

# %%
async with ApiClientUnified(verbose=False) as client:
    await client.get_pensioner_services(
        district=district_example,
        count=3,
        address_query = address
    )

# %%
async with ApiClientUnified(verbose=False) as client:
    await client.get_pet_parks(address)

# %%
# ------------- КРАСИВЫЕ МЕСТА -------------
async with ApiClientUnified(verbose=False) as client:
    await client.get_beautiful_places(address_query = address, count=3)

# %%
async with ApiClientUnified(verbose=False) as client:
    await client.get_beautiful_place_by_id(1)

# %%
async with ApiClientUnified(verbose=False) as client:
    await client.get_beautiful_places_area()

# %%
async with ApiClientUnified(verbose=False) as client:
    await client.get_beautiful_places_area_districts()

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_beautiful_places_categoria()

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_beautiful_places_keywords()

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_beautiful_place_routes(count=3)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_beautiful_place_routes_by_id(1)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_beautiful_place_routes_themes()

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_beautiful_place_routes_types()

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_news_role()



# ------------- GOSSTROY -------------

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_news_districts()

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_news(district=district_example, count=3)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_gosstroy_map(district=district_example)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_gosstroy_types()

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_gosstroy_categories()

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_gosstroy_statuses()

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_gosstroy_assignments()

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_gosstroy_info()

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_gosstroy_by_id(1)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_gosstroy_district_stats(district_example)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_memorable_dates_all()

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_memorable_dates_by_ids(1)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_memorable_dates_by_day(day=1, month=1)

# %%
# ------------- ПИТОМЦЫ (РАСШИРЕННЫЕ) -------------
async with ApiClientUnified(verbose=True) as client:
    await client.get_mypets_all_category(radius_km=5)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_mypets_animal_breeds(specie='Собака')

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_mypets_holidays()

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_mypets_posts(page=1, size=3)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_mypets_posts_id(1)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_mypets_recommendations_by_page(page=1, size=3)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_mypets_clinics_by_coord(lat=lat_spb, lon=lon_spb)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_mypets_clinics_id(1)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_mypets_parks_playground(lat=lat_spb, lon=lon_spb)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_mypets_parks_playground_id(1)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_mypets_shelters(lat=lat_spb, lon=lon_spb)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_mypets_shelters_id(1)

# %%
# ------------- СПОРТ (РАСШИРЕННЫЕ) -------------
async with ApiClientUnified(verbose=True) as client:
    await client.get_sport_event_by_id(1)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_sport_events_categoria(district_example)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_sport_events_map(district=district_example)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_sportgrounds_by_id(1)


# ------------- ГЕО ДОПОЛНИТЕЛЬНО -------------


# ------------- IPARENT -------------

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_sportgrounds_count_district(district_example)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_sportgrounds_types()

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_sportgrounds_map(district=district_example)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_municipality()

# %%
# ------------- ГАТИ -------------
async with ApiClientUnified(verbose=True) as client:
    await client.get_gati_orders_map()

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_gati_order_by_id(1)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_gati_work_types()

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_gati_work_types_raw()

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_gati_organizations()

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_gati_orders_district_stats()

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_gati_road_info(district_example)

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_iparent_places_categories()
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🚀 ApiAsyncClient initialized                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ──────────────────────────────────────── 📡 get_iparent_places_categories ─────────────────────────────────────────
#                              Request
#  URL:  https://yazzh.gate.petersburg.ru/iparent/places/categoria/
# Status: 200
# ╭─ Response JSON (get_iparent_places_categories) ─╮
# │ {                                               │
# │   "count": 11,                                  │
# │   "places_categoria": [                         │
# │     "Библиотеки",                               │
# │     "Зоопарки",                                 │
# │     "Игровые центры",                           │
# ...

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_iparent_places(categoria='Театры')
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🚀 ApiAsyncClient initialized                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ────────────────────────────────────────────── 📡 get_iparent_places ──────────────────────────────────────────────
#                             Request
#  URL:     https://yazzh.gate.petersburg.ru/iparent/places/all/
#  Params:  {'count': 10, 'page': 1, 'categoria': 'Театры'}
# Status: 200
# ╭───────────────────── Response JSON (get_iparent_places) ──────────────────────╮
# │ {                                                                             │
# │   "count": 15,                                                                │
# │   "data": [                                                                   │
# ...

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_iparent_place_by_id(1)
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🚀 ApiAsyncClient initialized                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ─────────────────────────────────────────── 📡 get_iparent_place_by_id ────────────────────────────────────────────
#                              Request
#  URL:     https://yazzh.gate.petersburg.ru/iparent/places/by_id/
#  Params:  {'id': 1}
# Status: 500
# ╭─ Response JSON (get_iparent_place_by_id) ─╮
# │ {                                         │
# │   "detail": "Data not found"              │
# │ }                                         │
# ╰───────────────────────────────────────────╯
# 👋 Client closed

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_iparent_recreations_categories()
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🚀 ApiAsyncClient initialized                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ────────────────────────────────────── 📡 get_iparent_recreations_categories ──────────────────────────────────────
#                                 Request
#  URL:  https://yazzh.gate.petersburg.ru/iparent/recreations/categoria/
# Status: 200
# ╭─ Response JSON (get_iparent_recreations_categories) ─╮
# │ {                                                    │
# │   "count": 16,                                       │
# │   "type": [                                          │
# │     "Все",                                           │
# │     "Обучающее занятие",                             │
# ...

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_iparent_recreations(count=3)
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🚀 ApiAsyncClient initialized                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ─────────────────────────────────────────── 📡 get_iparent_recreations ────────────────────────────────────────────
#                               Request
#  URL:     https://yazzh.gate.petersburg.ru/iparent/recreations/all/
#  Params:  {'page': 1, 'count': 3}
# - Error! Timeout: Request timed out
# 👋 Client closed

# %%
async with ApiClientUnified(verbose=True) as client:
    await client.get_iparent_recreation_by_id(1)
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🚀 ApiAsyncClient initialized                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ───────────────────────────────────────── 📡 get_iparent_recreation_by_id ─────────────────────────────────────────
#                            Request
#  URL:  https://yazzh.gate.petersburg.ru/iparent/recreations/1
# - Error! Timeout: Request timed out
# 👋 Client closed
