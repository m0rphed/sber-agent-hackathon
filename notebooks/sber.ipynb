# %%
from dataclasses import dataclass
import json
import os

# %%
DATA_DIR = 'DATA'
EMB_INDEX_PATH = 'embeddings_index.json'

GIGACHAT_MODEL = 'GigaChat-2'
EMBEDDINGS_MODEL = 'EmbeddingsGigaR'

CHUNK_SIZE = 800
CHUNK_OVERLAP = 200
TOP_K = 5

# %%
','.join(['a','b'])
# Out:
# 'a,b'
